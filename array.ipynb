// %%
String[]names={"harsha","vinay","sai"};
System.out.println(names[0]);
// Out:
// harsha

// %%
int num[]={10,20,30,40,50,60};
for(int i=0;i<num.length;i++){
    System.out.println(num[i]);
}
// Out:
// 10
// 20
// 30
// 40
// 50
// 60

// %%
int num={5,6,9,23,18};
int sum=0;
for(int i=0; i<num.length;i++){
    sum+=num[i];
}
System.out.println("the sum is",+sum);
// Out:
// |   int num={5,6,9,23,18};
// illegal initializer for int
